# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk import pos_tag

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')

text = 'hi love love hello'
 
tokens = word_tokenize(text)

print("Tokenized Words:")
print(tokens)


freq = FreqDist(tokens)

print("\nWord Frequency:")
print(freq)


stop_words = set(stopwords.words('english'))

filtered_words = [
    word for word in tokens
    if word.lower() not in stop_words and word.isalpha()
]

print("\nAfter Removing Stop Words:")
print(filtered_words)


pos_tags = pos_tag(filtered_words)

print("\nPOS Tagging:")
print(pos_tags)
# Out:
# Tokenized Words:
# ['hi', 'love', 'love', 'hello']
#
# Word Frequency:
# <FreqDist with 3 samples and 4 outcomes>
#
# After Removing Stop Words:
# ['hi', 'love', 'love', 'hello']
#
# POS Tagging:
# [('hi', 'NN'), ('love', 'VB'), ('love', 'NN'), ('hello', 'NN')]
# [nltk_data] Downloading package punkt to C:\Users\Sharayu
# [nltk_data]     Fugare\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Sharayu
# [nltk_data]     Fugare\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Sharayu Fugare\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
